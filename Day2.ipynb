# %% [markdown]
# 'Day2: 30 Days of python programming'

# %% [markdown]
# Exercises: Level 1

# %%
first_name = "nikhila"
print(first_name)
last_name = "jupally"
print(last_name)
full_name ="nikhila jupally"
print(full_name)
Country = "India"
print(Country)
City ="Indianapolis"
print(City)
age = 30
print(age)
year = 2026
print(year)
is_married ="yes"
print(is_married)
is_true="yes"
print(is_true)
is_light_on= 1
print(is_light_on)
multiple_variable = [2,3,4,5]
print(multiple_variable)
# Out:
# nikhila
# jupally
# nikhila jupally
# India
# Indianapolis
# 30
# 2026
# yes
# yes
# 1
# [2, 3, 4, 5]

# %% [markdown]
# Exercises: Level 2

# %%
first_name = "nikhila"
print(first_name)
print(len(first_name))
last_name = "jupally"
print(last_name)
print(len(last_name))
full_name ="nikhila jupally"
print(full_name)
print(len(full_name))
Country = "India"
print(Country)
print(len(Country))
City ="Indianapolis"
print(City)
print(len(City))
age = 30
print(age)
year = 2026
print(year)
is_married ="yes"
print(is_married)
print(len(is_married))
is_true="yes"
print(is_true)
print(len(is_true))
is_light_on= 1
print(is_light_on)
multiple_variable = [2,3,4,5]
print(multiple_variable)
print(len(multiple_variable))
# Out:
# nikhila
# 7
# jupally
# 7
# nikhila jupally
# 15
# India
# 5
# Indianapolis
# 12
# 30
# 2026
# yes
# 3
# yes
# 3
# 1
# [2, 3, 4, 5]
# 4

# %%
num_one= 5
num_two=4
add= num_one + num_two
print(add)
sub = num_two- num_one
print(sub)
multiply = num_one * num_two
print(multiply)
divide = num_one/num_two
print(divide)
modulus = num_two%num_one
print(modulus)
exponent= num_one** num_two
print(exponent)
floor_division = num_one//num_two
print(floor_division)
# Out:
# 9
# -1
# 20
# 1.25
# 4
# 625
# 1

# %%
last_name = input("Enter your last name: ")
print("Last Name:", last_name)
