# %% [markdown]
# # Exercise: Level 1

# %%
name = "Nikhila Jupally"
print(name)
# Out:
# Nikhila Jupally

# %%
Country = "India"
print(Country)
# Out:
# India

# %%
type(10)
# Out:
# int

# %%
type(9.8)
# Out:
# float

# %%
type(3.14)
# Out:
# float

# %%
x=(4-4j)
print(type(x))
# Out:
# <class 'complex'>

# %%
x=['Asabeneh','Python','Finland']
print(type(x))
# Out:
# <class 'list'>

# %%
name = "Nikhila Jupally"
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# Exercise: Level 2

# %% [markdown]
# Write an example for different Python data types such as Number(Integer, Float, Complex), String, Boolean, List, Tuple, Set and Dictionary.

# %%
print(type(3))
# Out:
# <class 'int'>

# %%
print(type(4+5J))
# Out:
# <class 'complex'>

# %%
print(type(2.75))
# Out:
# <class 'float'>

# %%
x='banana'
print(type(x))
# Out:
# <class 'str'>

# %%
y=["cat","dog","fish"]
print(type(y))
# Out:
# <class 'list'>

# %%
z=(1,2,3)
print(type(z))
# Out:
# <class 'tuple'>

# %%
w ={1,2,3}
print(type(w))
# Out:
# <class 'set'>

# %%
r = {'rose':'red','jasmine':'white','tulip':'yellow'}
print(type(r))
# Out:
# <class 'dict'>

# %% [markdown]
# **Euclidean distance between (2, 3) and (10, 8)**

# %%
p1=2
p2=3
q1=10
q2=8
p=p1-q1
q=p2-q2
import math
d= math.sqrt(p**2+q**2)
print(d)
# Out:
# 9.433981132056603
